# %%
import pandas as pd
red_df = pd.read_csv("Resources/scraped_Red.csv")
white_df = pd.read_csv("Resources/scraped_White.csv")
sparkling_df = pd.read_csv("Resources/scraped_Sparkling.csv")
rose_df = pd.read_csv("Resources/scraped_Rose.csv")

# %%
red_df["Type"] ="Red"
white_df["Type"] = "White"
sparkling_df["Type"] = "Sparkling"
rose_df["Type"] = "Rose"
rose_df.head()
# Out:
#                                Name   Country        Region  \
# 0        Mad Méditerranée Rosé 2019    France  Méditerranée
# 1                  Redoma Rosé 2019  Portugal         Douro
# 2  Fantini Cerasuolo d'Abruzzo 2019     Italy       Abruzzo
# 3            Mount Hermon Rosé 2017    Israel       Galilee
# 4                La Villa Rosé 2018    France     Languedoc
#
#                    Winery  Rating  Price  Year  Type
# 0      Château Camparnaud     4.0  10.11  2019  Rose
# 1                Niepoort     3.9  12.81  2019  Rose
# 2                 Farnese     3.6   5.60  2019  Rose
# 3                  Hermon     3.4  12.14  2017  Rose
# 4  Château La Sauvageonne     4.6  68.95  2018  Rose

# %%
combined_df = pd.concat([red_df, white_df, sparkling_df, rose_df])
combined_df
# Out:
#                                                   Name  Country  \
# 0                                         Pomerol 2011   France
# 1                                           Lirac 2017   France
# 2                   Erta e China Rosso di Toscana 2015    Italy
# 3                                       Bardolino 2019    Italy
# 4                       Ried Scheibner Pinot Noir 2016  Austria
# ..                                                 ...      ...
# 389                                          Rosé 2019   France
# 390  Rosa dei Frati Riviera del Garda Classico Rosé...    Italy
# 391                           Côte des Roses Rosé 2019   France
# 392                                        M Rosé 2019   France
# 393                         Whispering Angel Rosé 2019   France
#
#                         Region                 Winery  Rating  Price  Year  \
# 0                      Pomerol  Château La Providence     4.2  95.00  2011
# ...
